# %%
def qa(x):
  n = len(x)
  for i in range(1, n):
    v = x[i]
    j = i
    while j > 0 and v < x[j-1]:
      x[j] = x[j - 1]
      j = j - 1
    x[j] = v
    print(x)
  return x

# %%
x = [5, 2, 4, 3, 1]
x = qa(x)
# Out:
# [2, 5, 4, 3, 1]
# [2, 4, 5, 3, 1]
# [2, 3, 4, 5, 1]
# [1, 2, 3, 4, 5]

# %%
a = [1, 2, 3, 4, 5]
a, k = insertionSort(a)
print("Executou o laço mais interno", k," vezes")
# Out:
# Executou o laço mais interno 0  vezes

# %%
a = []
for i in range(0, 10000):
  a.append(a)
a, k = insertionSort(a)
print("Executou o laço mais interno", k," vezes")
# Out:
# Executou o laço mais interno 0  vezes
